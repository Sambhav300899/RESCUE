# %%
from samgeo import SamGeo3, download_file
from samgeo.common import show_image
# Out:
# /jet/home/rohatgi/lab/sam3/lib/python3.11/site-packages/sam3/model_builder.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
url = "https://raw.githubusercontent.com/facebookresearch/sam3/refs/heads/main/assets/images/test_image.jpg"
image_path = download_file(url)
# Out:
# Downloading...
# From: https://raw.githubusercontent.com/facebookresearch/sam3/refs/heads/main/assets/images/test_image.jpg
# To: /ocean/projects/cis240055p/rohatgi/RESCUE/notebooks/test_image.jpg
# 100%|██████████| 70.6k/70.6k [00:00<00:00, 13.6MB/s]

# %%
show_image(image_path)

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
sam3 = SamGeo3(
    backend="transformers", device=None, checkpoint_path=None, load_from_HF=True
)
# Out:
# Using cuda device and transformers backend
# config.json: 0.00B [00:00, ?B/s]
# /jet/home/rohatgi/lab/sam3/lib/python3.11/site-packages/huggingface_hub/file_download.py:718: UserWarning: Not enough free disk space to download the file. The expected file size is: 3439.94 MB. The target location /jet/home/rohatgi/.cache/huggingface/hub/models--facebook--sam3/blobs only has 3299.04 MB free disk space.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/lab/sam3/lib/python3.11/site-packages/transformers/modeling_utils.py:619, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs)
#     615 try:
#     616     # Load from URL or cache if already cached
#     617     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#     618     # result when internet is up, the repo and revision exist, but the file does not.
# --> 619     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#     621     # Try safetensors files first if not already found
#
# File ~/lab/sam3/lib/python3.11/site-packages/transformers/utils/hub.py:277, in cached_file(path_or_repo_id, filename, **kwargs)
#     227 """
#     228 Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     229
#    (...)    275 ```
#     276 """
# --> 277 file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     278 file = file[0] if file is not None else file
#
# File ~/lab/sam3/lib/python3.11/site-packages/transformers/utils/hub.py:508, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     507     elif not isinstance(e, EntryNotFoundError):
# --> 508         raise e
#     510 resolved_files = [
#     511     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     512 ]
#
# File ~/lab/sam3/lib/python3.11/site-packages/transformers/utils/hub.py:420, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     418 if len(full_filenames) == 1:
#     419     # This is slightly better for only 1 file
# --> 420     hf_hub_download(
#     421         path_or_repo_id,
#     422         filenames[0],
#     423         subfolder=None if len(subfolder) == 0 else subfolder,
#     424         repo_type=repo_type,
#     425         revision=revision,
#     426         cache_dir=cache_dir,
#     427         user_agent=user_agent,
#     428         force_download=force_download,
#     429         proxies=proxies,
#     430         token=token,
#     431         local_files_only=local_files_only,
#     432     )
#     433 else:
#
# File ~/lab/sam3/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~/lab/sam3/lib/python3.11/site-packages/huggingface_hub/file_download.py:982, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     981 else:
# --> 982     return _hf_hub_download_to_cache_dir(
#     983         # Destination
#     984         cache_dir=cache_dir,
#     985         # File info
#     986         repo_id=repo_id,
#     987         filename=filename,
#     988         repo_type=repo_type,
#     989         revision=revision,
#     990         # HTTP info
#     991         endpoint=endpoint,
#     992         etag_timeout=etag_timeout,
#     993         headers=hf_headers,
#     994         token=token,
#     995         # Additional options
#     996         local_files_only=local_files_only,
#     997         force_download=force_download,
#     998         tqdm_class=tqdm_class,
#     999         dry_run=dry_run,
#    1000     )
#
# File ~/lab/sam3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1198, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1197 with WeakFileLock(lock_path):
# -> 1198     _download_to_tmp_and_move(
#    1199         incomplete_path=Path(blob_path + ".incomplete"),
#    1200         destination_path=Path(blob_path),
#    1201         url_to_download=url_to_download,
#    1202         headers=headers,
#    1203         expected_size=expected_size,
#    1204         filename=filename,
#    1205         force_download=force_download,
#    1206         etag=etag,
#    1207         xet_file_data=xet_file_data,
#    1208         tqdm_class=tqdm_class,
#    1209     )
#    1210     if not os.path.exists(pointer_path):
#
# File ~/lab/sam3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1822, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1821     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1822     xet_get(
#    1823         incomplete_path=incomplete_path,
#    1824         xet_file_data=xet_file_data,
#    1825         headers=headers,
#    1826         expected_size=expected_size,
#    1827         displayed_filename=filename,
#    1828         tqdm_class=tqdm_class,
#    1829     )
#    1830 else:
#
# File ~/lab/sam3/lib/python3.11/site-packages/huggingface_hub/file_download.py:546, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     544     progress.update(progress_bytes)
# --> 546 download_files(
#     547     xet_download_info,
#     548     endpoint=connection_info.endpoint,
#     549     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     550     token_refresher=token_refresher,
#     551     progress_updater=[progress_updater],
#     552 )
#
# RuntimeError: Data processing error: CAS service error : IO Error: Disk quota exceeded (os error 122)
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sam3 = SamGeo3(
#       2     backend="transformers", device=None, checkpoint_path=None, load_from_HF=True
#       3 )
#
# File ~/lab/sam3/lib/python3.11/site-packages/samgeo/samgeo3.py:167, in SamGeo3.__init__(self, backend, model_id, bpe_path, device, eval_mode, checkpoint_path, load_from_HF, enable_segmentation, enable_inst_interactivity, compile_mode, resolution, confidence_threshold, mask_threshold, **kwargs)
#     154     self._init_meta_backend(
#     155         bpe_path=bpe_path,
#     156         device=device,
#    (...)    164         confidence_threshold=confidence_threshold,
#     165     )
#     166 else:  # transformers
# --> 167     self._init_transformers_backend(
#     168         model_id=model_id,
#     169         device=device,
#     170     )
#     172 # Common attributes
#     173 self.predictor = None
#
# File ~/lab/sam3/lib/python3.11/site-packages/samgeo/samgeo3.py:250, in SamGeo3._init_transformers_backend(self, model_id, device)
#     248 def _init_transformers_backend(self, model_id, device):
#     249     """Initialize Transformers SAM3 backend."""
# --> 250     self.model = Sam3Model.from_pretrained(model_id).to(device)
#     251     self.processor = TransformersSam3Processor.from_pretrained(model_id)
#
# File ~/lab/sam3/lib/python3.11/site-packages/transformers/modeling_utils.py:4060, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4055     logger.warning_once(
#    4056         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4057     )
#    4058     use_kernels = True
# -> 4060 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4061     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4062     variant=variant,
#    4063     gguf_file=gguf_file,
#    4064     use_safetensors=use_safetensors,
#    4065     download_kwargs=download_kwargs_with_commit,
#    4066     user_agent=user_agent,
#    4067     is_remote_code=cls.is_remote_code(),
#    4068     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4069 )
#    4071 is_quantized = hf_quantizer is not None
#    4073 if gguf_file:
#
# File ~/lab/sam3/lib/python3.11/site-packages/transformers/modeling_utils.py:699, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs)
#     696         raise
#     697     except Exception as e:
#     698         # For any other exception, we throw a generic error.
# --> 699         raise OSError(
#     700             f"Can't load the model for '{pretrained_model_name_or_path}'. If you were trying to load it"
#     701             " from 'https://huggingface.co/models', make sure you don't have a local directory with the"
#     702             f" same name. Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a"
#     703             f" directory containing a file named {_add_variant(WEIGHTS_NAME, variant)}."
#     704         ) from e
#     706 if is_local:
#     707     logger.info(f"loading weights file {archive_file}")
#
# OSError: Can't load the model for 'facebook/sam3'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'facebook/sam3' is the correct path to a directory containing a file named pytorch_model.bin.
