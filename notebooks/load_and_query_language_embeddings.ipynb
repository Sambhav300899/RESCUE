# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

# %%
from rescue.mapanything_pipeline import SceneQueryer

# %%
scene_query = SceneQueryer("../generated/language_features.safetensors", device="cuda")
# Out:
# [SceneQueryer] Loaded 1,522,920 points, feature dim=512

# %%
pts, sims = scene_query.query("top view of a building", top_k=100)

pts.shape, sims.shape
# Out:
# (torch.Size([100, 3]), torch.Size([100]))
